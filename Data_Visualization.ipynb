# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_76hd.csv")

# %%
df.columns, df.shape
# Out:
# (Index(['V1', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16', 'V18',
#         'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#         'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V35', 'V37', 'V38', 'V39',
#         'V40', 'V41', 'V43', 'V44', 'V51', 'V55', 'V56', 'V57', 'V58'],
#        dtype='object'),
#  (282, 40))

# %% [markdown]
# ## Observations from Stats of the data
#
# + 1. All columns have min = 0 and max =1
# + 2. There are no missing values

# %%
df.describe()
# Out:
#                V1          V3          V4          V9         V10         V11  \
# count  282.000000  282.000000  282.000000  282.000000  282.000000  282.000000
# mean     0.506794    0.529403    0.677305    0.026609    0.649595    0.011157
# std      0.293371    0.188606    0.468338    0.095857    0.111649    0.086691
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.250000    0.395833    0.000000    0.015504    0.597990    0.000000
# 50%      0.506734    0.541667    1.000000    0.015504    0.648241    0.003953
# 75%      0.763468    0.666667    1.000000    0.023256    0.698492    0.003953
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               V12         V14         V15         V16  ...         V39  \
# count  282.000000  282.000000  282.000000  282.000000  ...  282.000000
# mean     0.280927    0.168243    0.273641    0.148936  ...    0.020292
# std      0.116464    0.196375    0.284051    0.356658  ...    0.112065
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      0.196347    0.000000    0.000000    0.000000  ...    0.000000
# 50%      0.269406    0.101010    0.277778    0.000000  ...    0.000000
# 75%      0.344749    0.303030    0.555556    0.000000  ...    0.000000
# max      1.000000    1.000000    1.000000    1.000000  ...    1.000000
#
#               V40         V41         V43         V44         V51         V55  \
# count  282.000000  282.000000  282.000000  282.000000  282.000000  282.000000
# mean     0.167181    0.287234    0.449225    0.215130    0.406028    0.198961
# std      0.184089    0.305548    0.179846    0.308403    0.482375    0.147317
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.334259    0.000000    0.000000    0.071429
# 50%      0.129032    0.500000    0.435185    0.000000    0.000000    0.214286
# 75%      0.258065    0.500000    0.555556    0.333333    1.000000    0.321429
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               V56         V57         V58
# count  282.000000  282.000000  282.000000
# mean     0.188162    0.966101    0.453901
# std      0.145114    0.116288    0.498755
# min      0.000000    0.000000    0.000000
# 25%      0.086420    0.976190    0.000000
# 50%      0.172840    0.976190    0.000000
# 75%      0.271605    0.988095    1.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 40 columns]

# %%
##import matplotlib.pyplot as plt # is compulsory
df[['V22']].hist() # V3, V21
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B420912C8>]],
#       dtype=object)

# %%
df[['V58']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018B40F1E708>]],
#       dtype=object)

# %%
df[['V19','V21','V31']].boxplot()

# %%
df.plot.scatter(x='V21',y='V3')

# %%
df_ts = pd.read_csv("AirPassengers.csv")

# %%
df_ts.shape, df_ts.columns
# Out:
# ((144, 2), Index(['Month', 'No_Passengers'], dtype='object'))

# %%
df_ts['No_Passengers'].plot()

# %%
df_ma = pd.read_csv("MarketArrivals.csv")

# %%
df_ma.shape,df_ma.columns
# Out:
# ((10227, 10),
#  Index(['market', 'month', 'year', 'quantity', 'priceMin', 'priceMax',
#         'priceMod', 'state', 'city', 'date'],
#        dtype='object'))

# %%
df_ma = df_ma.select_dtypes(exclude=['object'])

# %%
df_ma.shape,df_ma.columns
# Out:
# ((10227, 5),
#  Index(['year', 'quantity', 'priceMin', 'priceMax', 'priceMod'], dtype='object'))

# %%
df_ma.plot()

# %%
df_ma.describe()
# Out:
#                year      quantity      priceMin      priceMax      priceMod
# count  10227.000000  1.022700e+04  10227.000000  10227.000000  10227.000000
# mean    2009.022294  7.660488e+04    646.944363   1212.760731    984.284345
# std        4.372841  1.244087e+05    673.121850    979.658874    818.471498
# min     1996.000000  2.000000e+01     16.000000    145.000000     80.000000
# 25%     2006.000000  8.898000e+03    209.000000    557.000000    448.000000
# 50%     2009.000000  2.746000e+04    440.000000    923.000000    747.000000
# 75%     2013.000000  8.835650e+04    828.000000   1527.000000   1248.000000
# max     2016.000000  1.639032e+06   6000.000000   8192.000000   6400.000000

# %%
df_ma[['year', 'priceMin', 'priceMax', 'priceMod']].plot()

# %%
df_ma[['priceMin', 'priceMax', 'priceMod']].plot()

# %%
df_ma[['priceMin', 'priceMax']].plot()

# %%
df['Cancer'].value_counts().plot.pie()

# %%
import seaborn as sb

# %%
sb.violinplot(x = "priceMin", data=df_ma)
plt.show()

# %%
sb.violinplot(x='V2',y='V3', data=df)
plt.show()

# %%
df[['V2','V3']].describe()
# Out:
#                V2          V3
# count  858.000000  858.000000
# mean     2.511655   16.979021
# std      1.644759    2.797653
# min      1.000000   10.000000
# 25%      2.000000   15.000000
# 50%      2.000000   17.000000
# 75%      3.000000   18.000000
# max     28.000000   32.000000

# %%
from statsmodels.graphics.mosaicplot import mosaic

# %%
#V24 V25
mosaic(df, ['V24', 'Cancer'], title='Mosaic')
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  OrderedDict([(('0', '0'), (0.0, 0.0, 0.9938651729696507, 0.8780533189640133)),
#               (('0', '1'),
#                (0.0,
#                 0.8813755781002259,
#                 0.9938651729696507,
#                 0.11862442189977401)),
#               (('1', '0'),
#                (0.99884029734776,
#                 0.0,
#                 0.0011597026522399817,
#                 0.9966777408637874)),
#               (('1', '1'),
#                (0.99884029734776, 1.0, 0.0011597026522399817, 0.0))]))

# %%
l = [['a','b','b','c','c','d','d','d']]
d = pd.DataFrame(l)

# %%
d = d.T

# %%
d.iloc[:,0].value_counts()
# Out:
# d    3
# b    2
# c    2
# a    1
# Name: 0, dtype: int64

# %%
d.median()
# Out:
# Series([], dtype: float64)

# %%
d.dtypes
# Out:
# 0    object
# dtype: object

# %%
[1,2,2,3] => 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-8ef86c216511> in <module>
# ----> 1 d.hist()
#
# D:\Installed_new\Anaconda\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, **kwargs)
#     206         layout=layout,
#     207         bins=bins,
# --> 208         **kwargs,
#     209     )
#     210
#
# D:\Installed_new\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#     387
#     388     if naxes == 0:
# --> 389         raise ValueError("hist method requires numerical columns, nothing to plot.")
#     390
#     391     fig, axes = _subplots(
#
# ValueError: hist method requires numerical columns, nothing to plot.
